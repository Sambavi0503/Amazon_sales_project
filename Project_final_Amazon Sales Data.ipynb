# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # IMPORTING DATASET

# %%
df=pd.read_csv(r'C:\Users\samba\Desktop\Imarticus\Project ML\Amazon_sales\Amazon Sale Report.csv')

# %%
##Reading the dataframe

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
# df.reset_index(inplace=True)
# df

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.dtypes # to check the datatypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df.isnull().sum() # to check the contains null value
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
# CONVERTING ALL COLUMN HEADER IN LOWER CASE AND REPLACING WITH UNDERSCORE

# %%
df.columns=[i.lower().strip().replace(' ','_')for i in df.columns]
df.columns=[i.lower().replace('-','_')for i in df.columns]
df.columns
# Out:
# Index(['index', 'order_id', 'date', 'status', 'fulfilment', 'sales_channel',
#        'ship_service_level', 'style', 'sku', 'category', 'size', 'asin',
#        'courier_status', 'qty', 'currency', 'amount', 'ship_city',
#        'ship_state', 'ship_postal_code', 'ship_country', 'promotion_ids',
#        'b2b', 'fulfilled_by', 'unnamed:_22'],
#       dtype='object')

# %%
#removing rows from the DataFrame df where the 'amount' column has missing values

# %%
df.dropna(subset=['amount'],inplace=True)

# %%
df.amount.isna().sum()
# Out:
# 0

# %%
# REMOVING UNWANTED COLUMNS

# %%
df.drop(['index','unnamed:_22','b2b','asin','sku','fulfilment','promotion_ids','fulfilled_by'],axis=1,inplace=True)
df
# Out:
#                    order_id      date                        status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        sales_channel ship_service_level    style       category size  \
# 0          Amazon.in           Standard   SET389            Set    S
# ...

# %%
df.amount.unique()
# Out:
# array([ 647.62,  406.  ,  329.  , ...,  708.58, 1244.  ,  639.  ])

# %%
df.isnull().sum()
# Out:
# order_id                 0
# date                     0
# status                   0
# sales_channel            0
# ship_service_level       0
# style                    0
# category                 0
# size                     0
# courier_status        5136
# qty                      0
# currency                 0
# amount                   0
# ship_city               31
# ship_state              31
# ship_postal_code        31
# ship_country            31
# dtype: int64

# %%
df.nunique()
# Out:
# order_id              113030
# date                      91
# status                    12
# sales_channel              1
# ship_service_level         2
# style                   1373
# category                   9
# size                      11
# courier_status             2
# qty                        7
# currency                   1
# amount                  1410
# ship_city               8704
# ship_state                68
# ship_postal_code        9273
# ship_country               1
# dtype: int64

# %%
# we are dropping these 3 columns since it has only one unique value
df.drop(['sales_channel','currency','ship_country'],axis=1,inplace= True)
df
# Out:
#                    order_id      date                        status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        ship_service_level    style       category size courier_status  qty  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df['ship_state'].value_counts()
# Out:
# MAHARASHTRA               21073
# KARNATAKA                 16394
# TAMIL NADU                10809
# TELANGANA                 10637
# UTTAR PRADESH              9947
#                           ...
# Mizoram                       1
# rajsthan                      1
# Punjab/Mohali/Zirakpur        1
# Rajsthan                      1
# PB                            1
# Name: ship_state, Length: 68, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
df['ship_state'].value_counts().plot(kind='bar', color='Yellow')
plt.title('Region based orders')
plt.xlabel('ship_state')
plt.ylabel('no of orders')
plt.show()

# %%
df['ship_state'].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'Gujarat', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'Goa', 'MEGHALAYA', 'GOA',
#        'TRIPURA', 'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'Delhi', nan,
#        'ANDAMAN & NICOBAR ', 'Punjab', 'Rajshthan', 'Manipur',
#        'rajasthan', 'Odisha', 'NL', 'Bihar', 'MIZORAM', 'punjab',
#        'New Delhi', 'Rajasthan', 'Punjab/Mohali/Zirakpur', 'Puducherry',
#        'delhi', 'RJ', 'Chandigarh', 'orissa', 'LAKSHADWEEP', 'goa', 'PB',
#        'Arunachal Pradesh', 'AR', 'Pondicherry', 'Sikkim',
#        'Arunachal pradesh', 'Nagaland', 'bihar', 'Mizoram', 'rajsthan',
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'date', 'status', 'ship_service_level', 'style', 'category',
#        'size', 'courier_status', 'qty', 'amount', 'ship_city', 'ship_state',
#        'ship_postal_code'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
df['status'].value_counts().plot(kind='pie',autopct='%1.1f%%', startangle=140, labeldistance=1.1)
plt.title('Types of status')
plt.xlabel('status')
plt.ylabel('status counts')
plt.show()

# %%
category=df['category'].value_counts().sort_values()
plt.figure(figsize=(10, 6))
category.plot(kind='barh',color='green')
plt.title('Types of categories')
plt.xlabel('category')
plt.ylabel('category counts')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['size'].value_counts().plot(kind='barh',color='red')
plt.title('Types of sizes')
plt.xlabel('size')
plt.ylabel('size counts')
plt.show()

# %%
state_amount=df.groupby('ship_state')['amount'].mean().sort_values().head(10)

# %%
plt.figure(figsize=(10, 6))
state_amount.plot(kind='bar',color='red')
plt.title('average_revenue_based_state')
plt.xlabel('state')
plt.ylabel('amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['courier_status'].value_counts().plot(kind='pie',autopct='%1.1f%%', startangle=140, labeldistance=1.1)
plt.title('Types of delivery method')
plt.xlabel('courier_status')
plt.ylabel('courier counts')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['ship_service_level'].value_counts().plot(kind='pie',autopct='%1.1f%%', startangle=140, labeldistance=1.1)
plt.title('Types of ship service level')
plt.xlabel('ship_service_level')
plt.ylabel('ship_service_level_counts')
plt.show()

# %%
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         ship_state  ship_postal_code  day  month  new_amount
# ...

# %% [markdown]
# # Data Cleaning

# %%
correct = {'AR': 'ARUNACHAL PRADESH',
    'NL': 'NAGALAND','PB':'PUNJAB','PUDUCHERRY':'Pondicherry','Punjab/Mohali/Zirakpur':'PUNJAB','Rajshthan':'RAJASTHAN','rajsthan':'RAJASTHAN',
           'RJ':'RAJASTHAN','Goa':'GOA','Gujarat':'GUJARAT'}
df['ship_state'] = df['ship_state'].replace(correct)

# %%
df['ship_state'].nunique()
# Out:
# 59

# %%
df.ship_state.value_counts(ascending=False)
# Out:
# MAHARASHTRA           21073
# KARNATAKA             16394
# TAMIL NADU            10809
# TELANGANA             10637
# UTTAR PRADESH          9947
# DELHI                  6393
# KERALA                 6151
# WEST BENGAL            5547
# ANDHRA PRADESH         5055
# HARYANA                4188
# GUJARAT                4153
# RAJASTHAN              2473
# MADHYA PRADESH         2367
# ODISHA                 1975
# BIHAR                  1935
# PUNJAB                 1762
# ASSAM                  1548
# UTTARAKHAND            1445
# JHARKHAND              1352
# GOA                    1076
# CHHATTISGARH            864
# HIMACHAL PRADESH        724
# JAMMU & KASHMIR         649
# Pondicherry             326
# CHANDIGARH              307
# MANIPUR                 296
# ANDAMAN & NICOBAR       243
# MEGHALAYA               195
# SIKKIM                  187
# NAGALAND                181
# Delhi                   156
# TRIPURA                 141
# ARUNACHAL PRADESH       135
# ...

# %%
correct= {'sales_channel': 'ARUNACHAL PRADESH',
    'NL': 'NAGALAND','PB':'PUNJAB','PUDUCHERRY':'Pondicherry','Punjab/Mohali/Zirakpur':'PUNJAB','Rajshthan':'RAJASTHAN','rajsthan':'RAJASTHAN',
           'RJ':'RAJASTHAN','Goa':'GOA','Gujarat':'GUJARAT'}
df['ship_state'] = df['ship_state'].replace(correct)

# %%
df.columns
# Out:
# Index(['order_id', 'date', 'status', 'ship_service_level', 'style', 'category',
#        'size', 'courier_status', 'qty', 'amount', 'ship_city', 'ship_state',
#        'ship_postal_code'],
#       dtype='object')

# %%
df.dtypes
# Out:
# order_id               object
# date                   object
# status                 object
# ship_service_level     object
# style                  object
# category               object
# size                   object
# courier_status         object
# qty                     int64
# amount                float64
# ship_city              object
# ship_state             object
# ship_postal_code      float64
# dtype: object

# %%
df.drop(columns=['order_id','style','ship_city'],inplace=True)

# %%
#feature Extraction

# %%
df['date'] = pd.to_datetime(df['date'])
# Extract day and month
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month

# %%
df.drop(columns=['date'],inplace=True)

# %%
df
# Out:
#                               status ship_service_level       category size  \
# 0                          Cancelled           Standard            Set    S
# 1       Shipped - Delivered to Buyer           Standard          kurta  3XL
# 2                            Shipped          Expedited          kurta   XL
# 3                          Cancelled           Standard  Western Dress    L
# 4                            Shipped          Expedited            Top  3XL
# ...                              ...                ...            ...  ...
# 128970                       Shipped          Expedited          kurta   XL
# 128971                       Shipped          Expedited            Set    M
# 128972                       Shipped          Expedited  Western Dress  XXL
# 128973                       Shipped          Expedited            Set   XS
# 128974                       Shipped          Expedited            Set    S
#
# ...

# %%
df.isna().sum()
# Out:
# status                   0
# ship_service_level       0
# category                 0
# size                     0
# courier_status        5136
# qty                      0
# amount                   0
# ship_state              31
# ship_postal_code        31
# day                      0
# month                    0
# dtype: int64

# %%
df.dropna(subset=['ship_state','ship_postal_code','courier_status'],inplace=True)

# %%
df.shape
# Out:
# (116016, 11)

# %%
df['courier_status'].value_counts()
# Out:
# Shipped      109461
# Unshipped      6555
# Name: courier_status, dtype: int64

# %%
correct= {'Shipped': 1,
    'Unshipped': 0}
df['courier_status'] = df['courier_status'].replace(correct)

# %%
df.dtypes
# Out:
# status                 object
# ship_service_level     object
# category               object
# size                   object
# courier_status          int64
# qty                     int64
# amount                float64
# ship_state             object
# ship_postal_code      float64
# day                     int64
# month                   int64
# dtype: object

# %%
df['status'] = [i.lower().rstrip() for i in df['status']]
df['status'].value_counts()
# Out:
# shipped                          77580
# shipped - delivered to buyer     28754
# cancelled                         5628
# shipped - returned to seller      1947
# shipped - picked up                973
# pending                            656
# pending - waiting for pick up      281
# shipped - returning to seller      145
# shipped - out for delivery          35
# shipped - rejected by buyer         11
# shipped - lost in transit            5
# shipped - damaged                    1
# Name: status, dtype: int64

# %%
correct={"cancelled":0,
"pending":1,
"pending - waiting for pick up":2,
"shipped":3,
"shipped - damaged":4,
"shipped - picked up":5,
"shipped - out for delivery":6,
"shipped - lost in transit":7,
"shipped - rejected by buyer":8,
"shipped - returning to seller":9,
"shipped - returned to seller":10,
"shipped - delivered to buyer":11}
df['status'] = df['status'].replace((correct))

# %%
df
# Out:
#         status ship_service_level       category size  courier_status  qty  \
# 1           11           Standard          kurta  3XL               1    1
# 2            3          Expedited          kurta   XL               1    1
# 4            3          Expedited            Top  3XL               1    1
# 5            3          Expedited            Set   XL               1    1
# 6            3          Expedited            Set    L               1    1
# ...        ...                ...            ...  ...             ...  ...
# 128970       3          Expedited          kurta   XL               1    1
# 128971       3          Expedited            Set    M               1    1
# 128972       3          Expedited  Western Dress  XXL               1    1
# 128973       3          Expedited            Set   XS               1    1
# 128974       3          Expedited            Set    S               1    1
#
#         amount     ship_state  ship_postal_code  day  month
# ...

# %%
df['status'].value_counts()
# Out:
# 3     77580
# 11    28754
# 0      5628
# 10     1947
# 5       973
# 1       656
# 2       281
# 9       145
# 6        35
# 8        11
# 7         5
# 4         1
# Name: status, dtype: int64

# %%
correct= {'Standard': 0,
    'Expedited': 1}
df['ship_service_level'] = df['ship_service_level'].replace(correct)

# %%
df
# Out:
#         status  ship_service_level       category size  courier_status  qty  \
# 1           11                   0          kurta  3XL               1    1
# 2            3                   1          kurta   XL               1    1
# 4            3                   1            Top  3XL               1    1
# 5            3                   1            Set   XL               1    1
# 6            3                   1            Set    L               1    1
# ...        ...                 ...            ...  ...             ...  ...
# 128970       3                   1          kurta   XL               1    1
# 128971       3                   1            Set    M               1    1
# 128972       3                   1  Western Dress  XXL               1    1
# 128973       3                   1            Set   XS               1    1
# 128974       3                   1            Set    S               1    1
#
# ...

# %%
correct={'Set':0,
'kurta':1,
'Western Dress':2,
'Top':3,
'Ethnic Dress':4,
'Bottom':5,
'Saree':6,
'Blouse':7,
'Dupatta':8}
df['category']=df['category'].replace(correct)

# %%
df
# Out:
#         status  ship_service_level  category size  courier_status  qty  \
# 1           11                   0         1  3XL               1    1
# 2            3                   1         1   XL               1    1
# 4            3                   1         3  3XL               1    1
# 5            3                   1         0   XL               1    1
# 6            3                   1         0    L               1    1
# ...        ...                 ...       ...  ...             ...  ...
# 128970       3                   1         1   XL               1    1
# 128971       3                   1         0    M               1    1
# 128972       3                   1         2  XXL               1    1
# 128973       3                   1         0   XS               1    1
# 128974       3                   1         0    S               1    1
#
#         amount     ship_state  ship_postal_code  day  month
# ...

# %%
correct={'XS':0,
'S':1,
'M':2,
'L':3,
'XL':4,
'XXL':5,
'3XL':6,
'4XL':7,
'5XL':8,
'6XL':9,
'Free':10}
df['size']=df['size'].replace(correct)

# %%
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         amount     ship_state  ship_postal_code  day  month
# ...

# %%
df['ship_state'] = [i.lower().strip().replace(' ','_') for i in df['ship_state']]
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         amount     ship_state  ship_postal_code  day  month
# ...

# %%
df['ship_state'].value_counts()
# Out:
# maharashtra          20273
# karnataka            15844
# tamil_nadu           10345
# telangana            10208
# uttar_pradesh         9462
# delhi                 6313
# kerala                5793
# west_bengal           5301
# andhra_pradesh        4795
# haryana               4043
# gujarat               3971
# rajasthan             2425
# madhya_pradesh        2258
# odisha                1901
# bihar                 1868
# punjab                1732
# assam                 1482
# uttarakhand           1383
# jharkhand             1279
# goa                   1051
# chhattisgarh           820
# himachal_pradesh       675
# jammu_&_kashmir        614
# pondicherry            307
# chandigarh             304
# manipur                294
# andaman_&_nicobar      223
# meghalaya              184
# sikkim                 182
# nagaland               172
# arunachal_pradesh      135
# tripura                134
# new_delhi               72
# mizoram                 67
# ...

# %%
correct={"andaman_&_nicobar":0,
"andhra_pradesh":1,
"arunachal_pradesh":2,
"assam":3,
"bihar":4,
"chandigarh":5,
"chhattisgarh":6,
"dadra_and_nagar":7,
"delhi":8,
"goa":9,
"gujarat":10,
"haryana":11,
"himachal_pradesh":12,
"jammu_&_kashmir":13,
"jharkhand":14,
"karnataka":15,
"kerala":16,
"ladakh":17,
"lakshadweep":18,
"madhya_pradesh":19,
"maharashtra":20,
"manipur":21,
"meghalaya":22,
"mizoram":23,
"nagaland":24,
"new_delhi":25,
"odisha":26,
"orissa":27,
"pondicherry":28,
"puducherry":29,
"punjab":30,
"rajasthan":31,
"rajsthan":32,
"sikkim":33,
"tamil_nadu":34,
"telangana":35,
"tripura":36,
"uttar_pradesh":37,
"uttarakhand":38,
"west_bengal":39}
df['ship_state']=df['ship_state'].replace(correct)

# %%
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         amount  ship_state  ship_postal_code  day  month
# ...

# %%
df.isna().sum()
# Out:
# status                0
# ship_service_level    0
# category              0
# size                  0
# courier_status        0
# qty                   0
# amount                0
# ship_state            0
# ship_postal_code      0
# day                   0
# month                 0
# dtype: int64

# %%
df.dtypes
# Out:
# status                  int64
# ship_service_level      int64
# category                int64
# size                    int64
# courier_status          int64
# qty                     int64
# amount                float64
# ship_state              int64
# ship_postal_code      float64
# day                     int64
# month                   int64
# dtype: object

# %%
# df['status'] = pd.to_numeric(df['status']).astype(int)
# df['ship_state'] = pd.to_numeric(df['ship_state']).astype(int)

# %%
df['ship_state'].value_counts()
# Out:
# 20    20273
# 15    15844
# 34    10345
# 35    10208
# 37     9462
# 8      6313
# 16     5793
# 39     5301
# 1      4795
# 11     4043
# 10     3971
# 31     2425
# 19     2258
# 26     1901
# 4      1868
# 30     1732
# 3      1482
# 38     1383
# 14     1279
# 9      1051
# 6       820
# 12      675
# 13      614
# 28      307
# 5       304
# 21      294
# 0       223
# 22      184
# 33      182
# 24      172
# 2       135
# 36      134
# 25       72
# 23       67
# 7        58
# 17       40
# 27        3
# 18        3
# 29        1
# 32        1
# Name: ship_state, dtype: int64

# %%
df['status'].value_counts()
# Out:
# 3     77580
# 11    28754
# 0      5628
# 10     1947
# 5       973
# 1       656
# 2       281
# 9       145
# 6        35
# 8        11
# 7         5
# 4         1
# Name: status, dtype: int64

# %%
df.dtypes
# Out:
# status                  int64
# ship_service_level      int64
# category                int64
# size                    int64
# courier_status          int64
# qty                     int64
# amount                float64
# ship_state              int64
# ship_postal_code      float64
# day                     int64
# month                   int64
# dtype: object

# %%
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         amount  ship_state  ship_postal_code  day  month
# ...

# %%
df['new_amount']=df['amount']
df.drop(columns=['amount'],inplace=True)
df.rename({'new_amount':'amount'},inplace=True)
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         ship_state  ship_postal_code  day  month  new_amount
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import *
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr
from scipy.stats import kstest
from scipy.stats import shapiro
from scipy.stats import anderson
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 1          406.0
# 2          329.0
# 4          574.0
# 5          824.0
# 6          653.0
#            ...
# 128970     517.0
# 128971     999.0
# 128972     690.0
# 128973    1199.0
# 128974     696.0
# Name: new_amount, Length: 116016, dtype: float64

# %%
x.shape,y.shape
# Out:
# ((116016, 10), (116016,))

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75,random_state=49)

# %%
# Linearity:
plt.figure(figsize=(20,15))
sns.heatmap(pd.concat([x_train,y_train],axis=1).corr(),annot=True,cmap='Reds')
plt.title('Correlation map of the Data',x=0.5,y=1)
plt.show()

# %%
def correlation(df,target):
    var_1,var_2,conclusion,p_value,corr_value = [],[],[],[],[]
    result_df = pd.DataFrame()
    for i in  df.columns:
        corr = pearsonr(df[i],target)
        var_1.append(i)
        var_2.append(target.name)
        corr_value.append(corr[0])
        p_value.append(corr[1])
        if corr[1]<0.05:
            conclusion.append('Significant')
        else:
            conclusion.append('In-Significant')
    result_df['ind_var'] = var_1
    result_df['dep_var'] = var_2
    result_df['corr_value'] = corr_value
    result_df['p_value'] = p_value
    result_df['conclusion'] = conclusion
    return result_df

# %%
correlation(x_train,y_train)
# Out:
#               ind_var     dep_var  corr_value       p_value      conclusion
# 0              status  new_amount   -0.006855  4.318005e-02     Significant
# 1  ship_service_level  new_amount    0.040137  2.307325e-32     Significant
# 2            category  new_amount   -0.269090  0.000000e+00     Significant
# 3                size  new_amount   -0.020647  1.122705e-09     Significant
# 4      courier_status  new_amount   -0.012601  2.015978e-04     Significant
# 5                 qty  new_amount    0.142806  0.000000e+00     Significant
# 6          ship_state  new_amount   -0.004424  1.919248e-01  In-Significant
# 7    ship_postal_code  new_amount   -0.041068  8.371590e-34     Significant
# 8                 day  new_amount    0.011433  7.450274e-04     Significant
# 9               month  new_amount    0.051661  1.676520e-52     Significant

# %%
def normality_check(df,variable):
    test_name = []
    conclusion = []
    var = []
    result_df = pd.DataFrame()
    for i in ['kstest','shapiro','anderson']:
        if i == 'kstest':
            test_name.append('Kolmogorov Smirnov test')
            var.append(variable)
            ks = kstest(df[variable],'norm')
            if ks[1]<0.05:
                conclusion.append('Non_normal')
            else:
                conclusion.append('Normal')
        elif i == 'shapiro':
            test_name.append('Shapiro Wilk test')
            var.append(variable)
            sha = shapiro(df[variable])
            if sha[1]<0.05:
                conclusion.append('Non_normal')
            else:
                conclusion.append('Normal')
        elif i == 'anderson':
            test_name.append('Anderson Darling test')
            var.append(variable)
            an = anderson(df[variable],'norm')
            if an[0]<an[1][2]:
                conclusion.append('Non_normal')
            else:
                conclusion.append('Normal')
        
    result_df['Variable'] = var
    result_df['Test_Name'] = test_name
    result_df['Conclusion'] = conclusion
    return result_df

# %%
normality_check(pd.DataFrame(y_train,columns=[y_train.name]),y_train.name)
# Out:
#      Variable                Test_Name  Conclusion
# 0  new_amount  Kolmogorov Smirnov test  Non_normal
# 1  new_amount        Shapiro Wilk test  Non_normal
# 2  new_amount    Anderson Darling test      Normal

# %%
#Multicollinearity
def multicollinearity(df):
    result_df = pd.DataFrame()
    vif_value, conclusion, var = [],[], []
    for i in range(df.shape[1]):
        var.append(df.iloc[:,i].name)
        vif = variance_inflation_factor(df.values,i)
        vif_value.append(vif)
        if vif <=5:
            conclusion.append('No Multicollinearity')
        elif (vif >5 ) & (vif <= 10):
            conclusion.append('Moderate Multicollinearity')
        elif (vif >10 ) & (vif <= 50):
            conclusion.append('High Multicollinearity')
        else:
            conclusion.append('Severe Multicollinearity')
    result_df['variable'] = var
    result_df['vif Value'] = vif_value
    result_df['conclusion'] = conclusion
    return result_df

# %%
result = multicollinearity(x_train)

# %%
result
# Out:
#              variable  vif Value                  conclusion
# 0              status  33.952300      High Multicollinearity
# 1  ship_service_level  36.848377      High Multicollinearity
# 2            category   1.786407        No Multicollinearity
# 3                size   3.747198        No Multicollinearity
# 4      courier_status  30.205827      High Multicollinearity
# 5                 qty  82.402182    Severe Multicollinearity
# 6          ship_state   4.577004        No Multicollinearity
# 7    ship_postal_code   6.774131  Moderate Multicollinearity
# 8                 day   3.837585        No Multicollinearity
# 9               month  31.930083      High Multicollinearity

# %%
from scipy.stats import bartlett,levene

# %%
for i in x_train.columns:
    print("x_train['%s']"%i,end=',')
# Out:
# x_train['status'],x_train['ship_service_level'],x_train['category'],x_train['size'],x_train['courier_status'],x_train['qty'],x_train['ship_state'],x_train['ship_postal_code'],x_train['day'],x_train['month'],

# %%
df
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 1           11                   0         1     6               1    1
# 2            3                   1         1     4               1    1
# 4            3                   1         3     6               1    1
# 5            3                   1         0     4               1    1
# 6            3                   1         0     3               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 128970       3                   1         1     4               1    1
# 128971       3                   1         0     2               1    1
# 128972       3                   1         2     5               1    1
# 128973       3                   1         0     0               1    1
# 128974       3                   1         0     1               1    1
#
#         ship_state  ship_postal_code  day  month  new_amount
# ...

# %%
bartlett(x_train['status'],x_train['ship_service_level'],x_train['category'],x_train['size'],x_train['courier_status'],x_train['qty'],x_train['ship_state'],x_train['ship_postal_code'],
x_train['day'],x_train['month'])
# Out:
# BartlettResult(statistic=16762457.124212205, pvalue=0.0)

# %%
levene(x_train['status'],x_train['ship_service_level'],x_train['category'],x_train['size'],x_train['courier_status'],x_train['qty'],x_train['ship_state'],x_train['ship_postal_code'],
x_train['day'],x_train['month'])
# Out:
# LeveneResult(statistic=146991.2421514613, pvalue=0.0)

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train_scaled = pd.DataFrame(sc.transform(x_train),columns=x_train.columns)
x_train_scaled
# Out:
#          status  ship_service_level  category      size  courier_status  \
# 0      1.642200           -1.569096 -0.878377  0.420498        0.243437
# 1     -0.541807            0.637310  0.008079 -0.098258        0.243437
# 2      1.642200           -1.569096  2.667448  0.939254        0.243437
# 3     -0.541807            0.637310  0.008079 -0.617014        0.243437
# 4     -0.541807            0.637310  0.894535 -1.654525        0.243437
# ...         ...                 ...       ...       ...             ...
# 87007 -0.541807            0.637310  0.008079  0.939254        0.243437
# 87008 -0.541807            0.637310  0.008079 -1.135770        0.243437
# 87009 -0.541807            0.637310  0.008079  0.939254        0.243437
# 87010  1.642200           -1.569096  0.008079 -0.098258        0.243437
# 87011 -0.541807            0.637310  0.008079 -0.098258        0.243437
#
#             qty  ship_state  ship_postal_code       day     month
# ...

# %%
for i in x_train.columns:
    print("x_train_scaled['%s']"%i,end=',')
# Out:
# x_train_scaled['status'],x_train_scaled['ship_service_level'],x_train_scaled['category'],x_train_scaled['size'],x_train_scaled['courier_status'],x_train_scaled['qty'],x_train_scaled['ship_state'],x_train_scaled['ship_postal_code'],x_train_scaled['day'],x_train_scaled['month'],

# %%
bartlett(x_train_scaled['status'],x_train_scaled['ship_service_level'],x_train_scaled['category'],x_train_scaled['size'],x_train_scaled['courier_status'],x_train_scaled['qty'],x_train_scaled['ship_state'],x_train_scaled['ship_postal_code']),
(x_train_scaled['day'],x_train_scaled['month'])
# Out:
# (0       -0.788018
#  1       -1.130152
#  2        0.238387
#  3        1.150746
#  4       -0.673973
#             ...
#  87007    0.238387
#  87008   -1.586332
#  87009    0.238387
#  87010    0.808611
#  87011    1.720970
#  Name: day, Length: 87012, dtype: float64,
#  0       -1.113194
#  1        1.328727
#  2       -1.113194
#  3        0.107766
#  4       -1.113194
#             ...
#  87007   -1.113194
#  87008    0.107766
#  87009    1.328727
#  87010    0.107766
#  87011   -1.113194
#  Name: month, Length: 87012, dtype: float64)

# %%
from sklearn.decomposition import PCA

# %%
pc = PCA()
pc
# Out:
# PCA()

# %%
x_train_pc=pd.DataFrame(pc.fit_transform(x_train_scaled),columns=['pc_%i'%i for i in range(1,x_train_scaled.shape[1]+1)])

# %%
x_train_pc
# Out:
#            pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 0     -2.319277 -0.388493  0.230378 -0.180237 -1.149861  1.450490  1.148607
# 1      0.905665  0.318324  1.622960  0.543544  0.250579 -0.791709 -0.811194
# 2     -2.470489  1.903179 -1.295950 -2.012664  0.424055  0.234914 -0.478924
# 3      0.722121 -0.532535 -0.732315  0.035594  0.410771 -0.523140 -0.449330
# 4      0.681933 -0.850721 -0.085944 -0.125301  0.101161  0.305386 -1.065619
# ...         ...       ...       ...       ...       ...       ...       ...
# 87007  0.595179  0.413164 -0.997345  1.699871 -1.040316  0.776239 -0.538053
# 87008  0.837904 -0.727181  1.435581  0.097962  0.195731 -0.207363 -1.108850
# 87009  0.824191  1.210994  0.354006  1.762991 -0.691828 -0.201359  0.390236
# 87010 -2.272282 -0.149010 -0.348561 -1.795943  0.442228 -0.111005  0.873146
# 87011  0.575105 -0.394747 -1.987916  1.159395 -0.520052  0.415636 -0.119022
#
#            pc_8      pc_9     pc_10
# ...

# %%
multicollinearity(x_train_pc)
# Out:
#   variable  vif Value            conclusion
# 0     pc_1        1.0  No Multicollinearity
# 1     pc_2        1.0  No Multicollinearity
# 2     pc_3        1.0  No Multicollinearity
# 3     pc_4        1.0  No Multicollinearity
# 4     pc_5        1.0  No Multicollinearity
# 5     pc_6        1.0  No Multicollinearity
# 6     pc_7        1.0  No Multicollinearity
# 7     pc_8        1.0  No Multicollinearity
# 8     pc_9        1.0  No Multicollinearity
# 9    pc_10        1.0  No Multicollinearity

# %%
pc.explained_variance_ratio_.cumsum()*100
# Out:
# array([ 20.45079944,  31.37151998,  42.08466012,  52.43468646,
#         62.43148227,  72.39446938,  81.95318619,  90.98551513,
#         99.65411907, 100.        ])

# %%
lr= LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train_pc,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_ #beta_value
beta = lr.coef_
beta
# Out:
# array([   6.13066888,  -41.50264416,   23.70774647,    0.44652287,
#          20.81415459,   34.3136596 ,   36.89721233,  -42.29810919,
#          31.51848217, -215.79938198])

# %%
lr.intercept_ # alpha_value
alpha = lr.intercept_ 
alpha
# Out:
# 649.6076288328047

# %%
kf= KFold(5)
result=cross_val_score(lr,x_train_pc,y_train,cv=kf)
result
# Out:
# array([0.11234182, 0.12597725, 0.11102708, 0.13221569, 0.11282006])

# %%
mae_train = mean_absolute_error(y_train,lr.predict(x_train_pc))
rmse_train = np.sqrt(mean_squared_error(y_train,lr.predict(x_train_pc)))
mape_train = mean_absolute_percentage_error(y_train,lr.predict(x_train_pc))

# %%
x_test
# Out:
#         status  ship_service_level  category  size  courier_status  qty  \
# 64766        3                   1         3     3               1    1
# 79471       11                   0         0     0               1    1
# 35179       11                   0         2     3               1    1
# 86886        3                   1         1     1               1    1
# 71697        3                   1         0     5               1    1
# ...        ...                 ...       ...   ...             ...  ...
# 88730        3                   1         0     3               1    1
# 80746       11                   0         2     5               1    1
# 46112        3                   1         1     5               1    1
# 72840        3                   1         0     2               1    1
# 124128      11                   0         2     5               1    1
#
#         ship_state  ship_postal_code  day  month
# 64766            8          110045.0   19      5
# ...

# %%
x_test_scalted = pd.DataFrame(sc.fit_transform(x_test),columns=x_test.columns,index = x_test.index)

# %%
x_test_scalted
# Out:
#           status  ship_service_level  category      size  courier_status  \
# 64766  -0.526788            0.626644  1.765949 -0.100797        0.248508
# 79471   1.675821           -1.595803 -0.875688 -1.650357        0.248508
# 35179   1.675821           -1.595803  0.885403 -0.100797        0.248508
# 86886  -0.526788            0.626644  0.004858 -1.133837        0.248508
# 71697  -0.526788            0.626644 -0.875688  0.932244        0.248508
# ...          ...                 ...       ...       ...             ...
# 88730  -0.526788            0.626644 -0.875688 -0.100797        0.248508
# 80746   1.675821           -1.595803  0.885403  0.932244        0.248508
# 46112  -0.526788            0.626644  0.004858  0.932244        0.248508
# 72840  -0.526788            0.626644 -0.875688 -0.617317        0.248508
# 124128  1.675821           -1.595803  0.885403  0.932244        0.248508
#
#              qty  ship_state  ship_postal_code       day     month
# ...

# %%
x_test_scaled_pc = pd.DataFrame(pc.transform(x_test_scalted), columns=[f'pc_{i}' for i in range(1, pc.n_components_ + 1)], index=x_test_scalted.index)

# %%
multicollinearity(x_test_scaled_pc)
# Out:
#   variable  vif Value            conclusion
# 0     pc_1   1.000228  No Multicollinearity
# 1     pc_2   1.000198  No Multicollinearity
# 2     pc_3   1.000668  No Multicollinearity
# 3     pc_4   1.000308  No Multicollinearity
# 4     pc_5   1.000364  No Multicollinearity
# 5     pc_6   1.000512  No Multicollinearity
# 6     pc_7   1.000766  No Multicollinearity
# 7     pc_8   1.000391  No Multicollinearity
# 8     pc_9   1.000157  No Multicollinearity
# 9    pc_10   1.001448  No Multicollinearity

# %%
x_test_pc_sig = x_test_scaled_pc[list(x_test_scaled_pc.columns)]

# %%
print("Shape of x_test_scaled_pc:", x_test_pc_sig.shape)
print("Shape of y_train:", y_train.shape)
# Out:
# Shape of x_test_scaled_pc: (29004, 10)
# Shape of y_train: (87012,)

# %%
# Assuming pc is the PCA model fit on x_train_pc_sig
# Assuming x_train_pc_sig contains the features used during training

# Subset x_test_pc_sig to include only the relevant features
x_test_pc_sig_subset = x_test_pc_sig[x_train_pc.columns]

# Predict using the subset of features
y_pred_test = lr.predict(x_test_pc_sig_subset)

# Calculate evaluation metrics
mae_test = mean_absolute_error(y_test, y_pred_test)
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
mape_test = mean_absolute_percentage_error(y_test, y_pred_test)

# %%
mertrics_train = [mae_train,rmse_train,mape_train]
mertrics_test = [mae_test,rmse_test,mape_test]

# %%
eval_df = pd.DataFrame()
eval_df['train_metrics'] = mertrics_train
eval_df['test_metrics'] = mertrics_test
eval_df.index = ['mae','rmse','mape']
eval_df
# Out:
#       train_metrics  test_metrics
# mae    2.123690e+02  2.121560e+02
# rmse   2.654137e+02  2.650608e+02
# mape   5.013342e+16  4.441493e+16

# %%
test_pred = lr.predict(x_test_pc_sig_subset)
test_pred
# Out:
# array([545.07914545, 721.61853088, 558.64035744, ..., 629.07326524,
#        709.61882845, 591.79360608])

# %%
obs_pred_df = pd.DataFrame()
obs_pred_df['obs'] = y_test.values
obs_pred_df['pred'] = test_pred

# %%
obs_pred_df.sort_values('pred',ascending=False)[:15].plot()
# Out:
# <Axes: >

# %%
obs_pred_df.sort_values('obs',ascending=False)[:15].plot()
# Out:
# <Axes: >

# %%
x_test_pc_sig_subset
# Out:
#             pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 64766   0.631057  1.009036 -0.583525 -2.137629  0.501217  0.098323 -0.343312
# 79471  -2.156905 -1.729499  1.333291 -0.769613  0.599071 -0.503453  0.142407
# 35179  -2.376199  0.146998 -0.134364 -0.310439  0.056521  0.156371 -0.474548
# 86886   0.811032 -0.741967  1.264089  0.103061  0.217805 -0.242143 -1.056756
# 71697   0.712291 -0.006519  0.338456 -0.098821 -0.215889  0.117260 -0.586562
# ...          ...       ...       ...       ...       ...       ...       ...
# 88730   0.813581 -0.536285  1.362906  1.399778 -0.452989  0.003494 -0.908473
# 80746  -2.289828  1.251489  0.684713 -0.404766 -0.023426 -0.077755 -0.109451
# 46112   0.591201  0.291482  0.481408 -1.805821 -0.524329  1.362163 -0.793219
# 72840   0.783289 -0.803743  0.528359  1.262279 -0.632339  0.289865  0.101806
# 124128 -2.149110  1.787442  1.461823  1.175631 -0.295025 -0.557038  0.382829
#
#             pc_8      pc_9     pc_10
# ...

# %%
y_pred_test.shape
# Out:
# (29004,)

# %%
x_test_pc_sig_subset
# Out:
#             pc_1      pc_2      pc_3      pc_4      pc_5      pc_6      pc_7  \
# 64766   0.631057  1.009036 -0.583525 -2.137629  0.501217  0.098323 -0.343312
# 79471  -2.156905 -1.729499  1.333291 -0.769613  0.599071 -0.503453  0.142407
# 35179  -2.376199  0.146998 -0.134364 -0.310439  0.056521  0.156371 -0.474548
# 86886   0.811032 -0.741967  1.264089  0.103061  0.217805 -0.242143 -1.056756
# 71697   0.712291 -0.006519  0.338456 -0.098821 -0.215889  0.117260 -0.586562
# ...          ...       ...       ...       ...       ...       ...       ...
# 88730   0.813581 -0.536285  1.362906  1.399778 -0.452989  0.003494 -0.908473
# 80746  -2.289828  1.251489  0.684713 -0.404766 -0.023426 -0.077755 -0.109451
# 46112   0.591201  0.291482  0.481408 -1.805821 -0.524329  1.362163 -0.793219
# 72840   0.783289 -0.803743  0.528359  1.262279 -0.632339  0.289865  0.101806
# 124128 -2.149110  1.787442  1.461823  1.175631 -0.295025 -0.557038  0.382829
#
#             pc_8      pc_9     pc_10
# ...

# %%
# plt.figure(figsize=(16, 6))
# plt.plot(x_test_pc_sig_subset['pc_1'], y_pred_test, label='Test score')
# plt.plot(x_train_pc['pc_1'], y_train, label='train score')
# plt.xlabel('pc_1')
# plt.ylabel('Predicted values')
# plt.title("Optimal Number of Features")
# plt.legend(loc='upper left')
# plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
base_estimator = DecisionTreeClassifier(max_depth=1)
base_estimator.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# # Assuming x_train_scaled, x_test, y_train, and y_test are already defined

# # Define base estimator
# base_estimator = DecisionTreeClassifier(max_depth=1)

# # Fit an AdaBoost model on the training set
# adaboost = AdaBoostClassifier(base_estimator=base_estimator, n_estimators=50, learning_rate=1.0, random_state=42)
# adaboost.fit(x_train_scaled, y_train)

# # Evaluate the performance of the model on the tes

# %%
base_regressor = DecisionTreeRegressor(max_depth=3)
ada_boost_regressor = AdaBoostRegressor(base_regressor, n_estimators=50, learning_rate=0.1, random_state=42)

# %%
ada_boost_regressor.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3),
#                   learning_rate=0.1, random_state=42)

# %%
predictions = ada_boost_regressor.predict(x_test)

# %%
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 49635.9669276032
# R-squared: 0.37610543913137884

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 0.2]
}

grid_search = GridSearchCV(AdaBoostRegressor(base_regressor, random_state=42), param_grid, cv=5)
grid_search.fit(x_train, y_train)

best_model = grid_search.best_estimator_

# %%
# Create a decision tree regressor
regressor = DecisionTreeRegressor(random_state=42)

# Fit the model to the training data
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Make predictions on the test set
y_pred = regressor.predict(x_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 79718.07206659214

# %%
# Standardize the features
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
k_value = 5  # You can choose the appropriate k value based on cross-validation
knn_model = KNeighborsRegressor(n_neighbors=k_value)
knn_model.fit(x_train_scaled, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Make predictions
y_pred = knn_model.predict(x_test_scaled)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 49693.157032133495
# R-squared: 0.3753865935570798

# %%
tree_model = DecisionTreeRegressor(random_state=42)
tree_model.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Make predictions
y_pred_tree = tree_model.predict(x_test_scaled)

# Evaluate the model
mse_tree = mean_squared_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)

print(f'Mean Squared Error (Tree): {mse_tree}')
print(f'R-squared (Tree): {r2_tree}')
# Out:
# Mean Squared Error (Tree): 79680.34999856322
# R-squared (Tree): -0.0015345736030396573

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 44795.44046720365
# R-squared: 0.4369479756490763

# %%
feature_importance = rf_model.feature_importances_
feature_names = x.columns

# Create a DataFrame to display feature importance
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#               Feature  Importance
# 2            category    0.391803
# 7    ship_postal_code    0.248537
# 8                 day    0.133330
# 3                size    0.092352
# 0              status    0.040444
# 9               month    0.032563
# 5                 qty    0.023525
# 6          ship_state    0.022699
# 4      courier_status    0.009029
# 1  ship_service_level    0.005718
