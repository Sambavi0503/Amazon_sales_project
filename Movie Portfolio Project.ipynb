# %%
! pip install jupyter
# Out:
# Requirement already satisfied: jupyter in c:\users\samba\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: nbconvert in c:\users\samba\anaconda3\lib\site-packages (from jupyter) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\samba\anaconda3\lib\site-packages (from jupyter) (5.4.0)
# Requirement already satisfied: ipywidgets in c:\users\samba\anaconda3\lib\site-packages (from jupyter) (7.6.5)
# Requirement already satisfied: ipykernel in c:\users\samba\anaconda3\lib\site-packages (from jupyter) (6.19.2)
# Requirement already satisfied: notebook in c:\users\samba\anaconda3\lib\site-packages (from jupyter) (6.5.2)
# Requirement already satisfied: jupyter-console in c:\users\samba\anaconda3\lib\site-packages (from jupyter) (6.6.2)
# Requirement already satisfied: packaging in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (22.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: psutil in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.7.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (7.3.4)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.10.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\samba\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\samba\anaconda3\lib\site-packages (from ipywidgets->jupyter) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\samba\anaconda3\lib\site-packages (from ipywidgets->jupyter) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\samba\anaconda3\lib\site-packages (from ipywidgets->jupyter) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\samba\anaconda3\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\samba\anaconda3\lib\site-packages (from jupyter-console->jupyter) (3.0.36)
# Requirement already satisfied: pygments in c:\users\samba\anaconda3\lib\site-packages (from jupyter-console->jupyter) (2.17.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\samba\anaconda3\lib\site-packages (from jupyter-console->jupyter) (5.2.0)
# Requirement already satisfied: jinja2>=3.0 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: tinycss2 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.1.1)
# Requirement already satisfied: lxml in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.9.1)
# Requirement already satisfied: bleach in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\samba\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\samba\anaconda3\lib\site-packages (from notebook->jupyter) (0.5.2)
# Requirement already satisfied: argon2-cffi in c:\users\samba\anaconda3\lib\site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\samba\anaconda3\lib\site-packages (from notebook->jupyter) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\samba\anaconda3\lib\site-packages (from notebook->jupyter) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\samba\anaconda3\lib\site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\samba\anaconda3\lib\site-packages (from qtconsole->jupyter) (2.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\samba\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: colorama in c:\users\samba\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\samba\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\samba\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: backcall in c:\users\samba\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\samba\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samba\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\samba\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\samba\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\samba\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\samba\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\samba\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\samba\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\samba\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\samba\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\samba\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\samba\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.3.2.post1)
# Requirement already satisfied: six>=1.9.0 in c:\users\samba\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\samba\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\samba\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\samba\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\samba\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\samba\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\samba\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\samba\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: executing in c:\users\samba\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\samba\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\samba\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: idna>=2.8 in c:\users\samba\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\samba\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\samba\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)

# %% [markdown]
# ## importing certain libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import matplotlib

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)

# %%
df=pd.read_csv(r"C:\Users\samba\Desktop\Github\movies.csv\movies.csv")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# ## TO check the column contains null value

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %% [markdown]
# ## To Check the value counts

# %%
df['rating'].value_counts()
# Out:
# R            3697
# PG-13        2112
# PG           1252
# Not Rated     283
# G             153
# Unrated        52
# NC-17          23
# TV-MA           9
# TV-PG           5
# X               3
# Approved        1
# TV-14           1
# Name: rating, dtype: int64

# %%
df['budget'] = df['budget'].fillna(df['budget'].mean())

# %%
df['gross'] = df['gross'].fillna(df['gross'].mean())

# %%
df['runtime'] = df['runtime'].fillna(df['runtime'].mean())

# %%
df['budget'].isna().sum()
# Out:
# 0

# %%
df['budget'].unique
# Out:
# <bound method Series.unique of 0       19000000
# 1        4500000
# 2       18000000
# 3        3500000
# 4        6000000
#           ...
# 7663        7000
# 7664    35589876
# 7665       58750
# 7666       15000
# 7667    35589876
# Name: budget, Length: 7668, dtype: int64>

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%
# yearcorrect - 0%

# %% [markdown]
# # to check the data types

# %%
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross          float64
# company         object
# runtime        float64
# yearcorrect     object
# dtype: object

# %%
df['budget']=df['budget'].astype('int64')

# df['gross']=df['gross'].astype('int64')

df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country    budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000
# 2              Leigh Brackett       Mark Hamill   United States  18000000
# 3                Jim Abrahams       Robert Hays   United States   3500000
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000
# ...                       ...               ...             ...       ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000
# 7664              Lisa Huston  Michael Saquella   United States  35589876
# 7665             Lynno Lovert      Onyama Laura   United States     58750
# 7666            James Randall     Christina Roz   United States     15000
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa  35589876
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
df['gross']=df['gross'].astype('int64')

# %%
df.isnull().sum()
# Out:
# name            0
# rating         77
# genre           0
# year            0
# released        2
# score           3
# votes           3
# director        0
# writer          3
# star            1
# country         3
# budget          0
# gross           0
# company        17
# runtime         0
# yearcorrect     0
# dtype: int64

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
# ...                                 ...    ...        ...            ...
# 7663   October 23, 2020 (United States)    3.1       18.0  Joseph Ebanks
# 7664   February 7, 2020 (United States)    4.7       36.0   Dusty Dukatz
# 7665          April 27, 2020 (Cameroon)    5.7       29.0   Nkanya Nkwai
# 7666    October 1, 2020 (United States)    NaN        NaN  James Randall
# 7667    August 19, 2020 (United States)    5.7        7.0   Pereko Mosia
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
# ...                  ...                ...            ...        ...
# 7663       Joseph Ebanks       Shannon Bond  United States       7000
# 7664         Lisa Huston   Michael Saquella  United States   35589876
# 7665        Lynno Lovert       Onyama Laura  United States      58750
# 7666       James Randall      Christina Roz  United States      15000
# 7667        Pereko Mosia   Siyabonga Mabaso   South Africa   35589876
#
#              gross                    company  runtime yearcorrect
# 5445  2.847246e+09      Twentieth Century Fox    162.0      Decemb
# 7445  2.797501e+09             Marvel Studios    181.0      April
# 3045  2.201647e+09      Twentieth Century Fox    194.0      Decemb
# 6663  2.069522e+09                  Lucasfilm    138.0      Decemb
# 7244  2.048360e+09             Marvel Studios    149.0      April
# ...            ...                        ...      ...         ...
# 7663           NaN                        NaN     90.0      Octobe
# 7664           NaN  Cactus Blue Entertainment     90.0      Februa
# 7665           NaN           Embi Productions      NaN      April
# 7666           NaN                        NaN    120.0      Octobe
# 7667           NaN                PK 65 Films    102.0      August
#
# [7668 rows x 16 columns]

# %%
# removing duplicate records
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 60                               Herbie Goes Bananas          G  Adventure
# 78                                           Babylon        NaN      Drama
# 83                      The King and the Mockingbird  Not Rated  Animation
# 96                                     The Evil Dead      NC-17     Horror
# 120                               Tarzan the Ape Man   Approved  Adventure
# 201                                         Longshot      TV-PG     Comedy
# 476                                             Dune      PG-13     Action
# 691                                      Re-Animator    Unrated     Comedy
# 982                               Devil in the Flesh          X      Drama
# 2689                              Ghost in the Shell      TV-MA  Animation
# 7607                                           Furie      TV-14     Action
#
#       year                           released  score      votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000.0
# 2     1980      June 20, 1980 (United States)    8.7  1200000.0
# 60    1980      June 25, 1980 (United States)    5.0     5300.0
# 78    1980     November 1980 (United Kingdom)    7.4     1300.0
# 83    1980            March 19, 1980 (France)    7.9     4800.0
# 96    1981     April 15, 1983 (United States)    7.5   192000.0
# 120   1981      July 24, 1981 (United States)    3.4     5300.0
# 201   1981               1981 (United States)    5.1      101.0
# 476   1984  December 14, 1984 (United States)    6.5   132000.0
# 691   1985   October 18, 1985 (United States)    7.2    59000.0
# 982   1986       May 22, 1987 (United States)    5.8     1400.0
# 2689  1995     March 29, 1996 (United States)    8.0   133000.0
# 7607  2019        February 22, 2019 (Vietnam)    6.3     4200.0
#
#               director                   writer                  star  \
# 0      Stanley Kubrick             Stephen King        Jack Nicholson
# 2       Irvin Kershner           Leigh Brackett           Mark Hamill
# 60    Vincent McEveety                 Don Tait  Charles Martin Smith
# 78        Franco Rosso             Franco Rosso       David N. Haynes
# 83       Paul Grimault  Hans Christian Andersen           Jean Martin
# 96           Sam Raimi                Sam Raimi        Bruce Campbell
# 120         John Derek                 Tom Rowe              Bo Derek
# 201    E.W. Swackhamer              Barry Rosen          Leif Garrett
# 476        David Lynch            Frank Herbert       Kyle MacLachlan
# 691      Stuart Gordon           H.P. Lovecraft         Jeffrey Combs
# 982   Marco Bellocchio         Marco Bellocchio     Maruschka Detmers
# 2689      Mamoru Oshii          Shirow Masamune         Atsuko Tanaka
# 7607       Le-Van Kiet              Le-Van Kiet          Veronica Ngo
#
#              country    budget      gross                     company  \
# 0     United Kingdom  19000000   46998772                Warner Bros.
# 2      United States  18000000  538375067                   Lucasfilm
# 60     United States  35589876   18000000     Walt Disney Productions
# 78    United Kingdom  35589876     109749             Diversity Music
# 83            France  35589876     167451     Les Films Paul Grimault
# 96     United States    350000    2956630        Renaissance Pictures
# 120    United States   6500000   36565280   Metro-Goldwyn-Mayer (MGM)
# 201    United States  35589876   78500541                   Greentree
# 476    United States  40000000   30925690  Dino De Laurentiis Company
# 691    United States    900000    2023414             Empire Pictures
# 982            Italy  35589876     546904                   L.P. Film
# 2689           Japan  35589876     516540                    Kôdansha
# 7607         Vietnam  35589876    5756185            Premiere Picture
#
#       runtime yearcorrect
# 0       146.0      June 1
# 2       124.0      June 2
# 60      100.0      June 2
# 78       95.0      Novemb
# 83       83.0      March
# 96       85.0      April
# 120     115.0      July 2
# 201     100.0      1981 (
# 476     137.0      Decemb
# 691     104.0      Octobe
# 982     114.0      May 22
# 2689     83.0      March
# 7607     98.0      Februa

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                                 name     rating      genre  \
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 201                                         Longshot      TV-PG     Comedy
# 0                                        The Shining          R      Drama
# 120                               Tarzan the Ape Man   Approved  Adventure
# 476                                             Dune      PG-13     Action
# 60                               Herbie Goes Bananas          G  Adventure
# 7607                                           Furie      TV-14     Action
# 96                                     The Evil Dead      NC-17     Horror
# 691                                      Re-Animator    Unrated     Comedy
# 982                               Devil in the Flesh          X      Drama
# 2689                              Ghost in the Shell      TV-MA  Animation
# 83                      The King and the Mockingbird  Not Rated  Animation
# 78                                           Babylon        NaN      Drama
#
#       year                           released  score      votes  \
# 2     1980      June 20, 1980 (United States)    8.7  1200000.0
# 201   1981               1981 (United States)    5.1      101.0
# 0     1980      June 13, 1980 (United States)    8.4   927000.0
# 120   1981      July 24, 1981 (United States)    3.4     5300.0
# 476   1984  December 14, 1984 (United States)    6.5   132000.0
# 60    1980      June 25, 1980 (United States)    5.0     5300.0
# 7607  2019        February 22, 2019 (Vietnam)    6.3     4200.0
# 96    1981     April 15, 1983 (United States)    7.5   192000.0
# 691   1985   October 18, 1985 (United States)    7.2    59000.0
# 982   1986       May 22, 1987 (United States)    5.8     1400.0
# 2689  1995     March 29, 1996 (United States)    8.0   133000.0
# 83    1980            March 19, 1980 (France)    7.9     4800.0
# 78    1980     November 1980 (United Kingdom)    7.4     1300.0
#
#               director                   writer                  star  \
# 2       Irvin Kershner           Leigh Brackett           Mark Hamill
# 201    E.W. Swackhamer              Barry Rosen          Leif Garrett
# 0      Stanley Kubrick             Stephen King        Jack Nicholson
# 120         John Derek                 Tom Rowe              Bo Derek
# 476        David Lynch            Frank Herbert       Kyle MacLachlan
# 60    Vincent McEveety                 Don Tait  Charles Martin Smith
# 7607       Le-Van Kiet              Le-Van Kiet          Veronica Ngo
# 96           Sam Raimi                Sam Raimi        Bruce Campbell
# 691      Stuart Gordon           H.P. Lovecraft         Jeffrey Combs
# 982   Marco Bellocchio         Marco Bellocchio     Maruschka Detmers
# 2689      Mamoru Oshii          Shirow Masamune         Atsuko Tanaka
# 83       Paul Grimault  Hans Christian Andersen           Jean Martin
# 78        Franco Rosso             Franco Rosso       David N. Haynes
#
#              country    budget      gross                     company  \
# 2      United States  18000000  538375067                   Lucasfilm
# 201    United States  35589876   78500541                   Greentree
# 0     United Kingdom  19000000   46998772                Warner Bros.
# 120    United States   6500000   36565280   Metro-Goldwyn-Mayer (MGM)
# 476    United States  40000000   30925690  Dino De Laurentiis Company
# 60     United States  35589876   18000000     Walt Disney Productions
# 7607         Vietnam  35589876    5756185            Premiere Picture
# 96     United States    350000    2956630        Renaissance Pictures
# 691    United States    900000    2023414             Empire Pictures
# 982            Italy  35589876     546904                   L.P. Film
# 2689           Japan  35589876     516540                    Kôdansha
# 83            France  35589876     167451     Les Films Paul Grimault
# 78    United Kingdom  35589876     109749             Diversity Music
#
#       runtime yearcorrect
# 2       124.0      June 2
# 201     100.0      1981 (
# 0       146.0      June 1
# 120     115.0      July 2
# 476     137.0      Decemb
# 60      100.0      June 2
# 7607     98.0      Februa
# 96       85.0      April
# 691     104.0      Octobe
# 982     114.0      May 22
# 2689     83.0      March
# 83       83.0      March
# 78       95.0      Novemb

# %%
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
sns.regplot(x="score", y="gross", data=df)
# Out:
# <Axes: xlabel='score', ylabel='gross'>

# %%
# Correlation Matrix between all numeric columns

df.corr(method ='pearson')
# Out:
# C:\Users\samba\AppData\Local\Temp\ipykernel_20860\2805906452.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='pearson')
#              year     score     votes    budget     gross   runtime
# year     1.000000 -0.021987 -0.226581  0.255045 -0.195022 -0.208971
# score   -0.021987  1.000000  0.587857 -0.046693  0.320245  0.002302
# votes   -0.226581  0.587857  1.000000 -0.266815  0.786899  0.579335
# budget   0.255045 -0.046693 -0.266815  1.000000 -0.146959 -0.066769
# gross   -0.195022  0.320245  0.786899 -0.146959  1.000000  0.336978
# runtime -0.208971  0.002302  0.579335 -0.066769  0.336978  1.000000

# %%
df.corr(method ='kendall')
# Out:
# C:\Users\samba\AppData\Local\Temp\ipykernel_20860\4097923626.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='kendall')
#              year     score     votes    budget     gross   runtime
# year     1.000000 -0.182574 -0.113081  0.082144 -0.210663 -0.099594
# score   -0.182574  1.000000  0.503236 -0.164971 -0.102564 -0.181834
# votes   -0.113081  0.503236  1.000000 -0.362267  0.296780  0.248371
# budget   0.082144 -0.164971 -0.362267  1.000000 -0.134976 -0.045580
# gross   -0.210663 -0.102564  0.296780 -0.134976  1.000000  0.519524
# runtime -0.099594 -0.181834  0.248371 -0.045580  0.519524  1.000000

# %%
df.corr(method ='spearman')
# Out:
# C:\Users\samba\AppData\Local\Temp\ipykernel_20860\1164575377.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='spearman')
#              year     score     votes    budget     gross   runtime
# year     1.000000 -0.261516 -0.148017  0.142149 -0.193294 -0.128268
# score   -0.261516  1.000000  0.635489 -0.203087 -0.104396 -0.088155
# votes   -0.148017  0.635489  1.000000 -0.466548  0.341128  0.321380
# budget   0.142149 -0.203087 -0.466548  1.000000 -0.203087 -0.101824
# gross   -0.193294 -0.104396  0.341128 -0.203087  1.000000  0.702482
# runtime -0.128268 -0.088155  0.321380 -0.101824  0.702482  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()
# Out:
# C:\Users\samba\AppData\Local\Temp\ipykernel_20860\1279345923.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# rating       0.967033  1.000000  0.273268  0.922410  0.967033  0.967033
# genre        0.237624  0.273268  1.000000  0.027277  0.237624  0.237624
# year         0.922410  0.922410  0.027277  1.000000  0.922410  0.922410
# released     1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# score        1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# votes        0.960719  0.924916  0.229283  0.920425  0.960719  0.960719
# director     1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# writer       1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# star         1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# country      0.769234  0.797724 -0.018956  0.872775  0.769234  0.769234
# budget       0.450974  0.411183  0.443463  0.213157  0.450974  0.450974
# gross        1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# company      1.000000  0.967033  0.237624  0.922410  1.000000  1.000000
# runtime      0.822996  0.782186  0.019233  0.749520  0.822996  0.822996
# yearcorrect  0.854302  0.828016  0.162871  0.730768  0.854302  0.854302
#
#                 votes  director    writer      star   country    budget  \
# name         0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# rating       0.924916  0.967033  0.967033  0.967033  0.797724  0.411183
# genre        0.229283  0.237624  0.237624  0.237624 -0.018956  0.443463
# year         0.920425  0.922410  0.922410  0.922410  0.872775  0.213157
# released     0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# score        0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# votes        1.000000  0.960719  0.960719  0.960719  0.791380  0.351262
# director     0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# writer       0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# star         0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# country      0.791380  0.769234  0.769234  0.769234  1.000000 -0.079357
# budget       0.351262  0.450974  0.450974  0.450974 -0.079357  1.000000
# gross        0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# company      0.960719  1.000000  1.000000  1.000000  0.769234  0.450974
# runtime      0.767655  0.822996  0.822996  0.822996  0.590057  0.593624
# yearcorrect  0.802079  0.854302  0.854302  0.854302  0.539956  0.543037
#
#                 gross   company   runtime  yearcorrect
# name         1.000000  1.000000  0.822996     0.854302
# rating       0.967033  0.967033  0.782186     0.828016
# genre        0.237624  0.237624  0.019233     0.162871
# year         0.922410  0.922410  0.749520     0.730768
# released     1.000000  1.000000  0.822996     0.854302
# score        1.000000  1.000000  0.822996     0.854302
# votes        0.960719  0.960719  0.767655     0.802079
# director     1.000000  1.000000  0.822996     0.854302
# writer       1.000000  1.000000  0.822996     0.854302
# star         1.000000  1.000000  0.822996     0.854302
# country      0.769234  0.769234  0.590057     0.539956
# budget       0.450974  0.450974  0.593624     0.543037
# gross        1.000000  1.000000  0.822996     0.854302
# company      1.000000  1.000000  0.822996     0.854302
# runtime      0.822996  0.822996  1.000000     0.912360
# yearcorrect  0.854302  0.854302  0.912360     1.000000

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name         name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# rating       name           0.967033
#              rating         1.000000
#              genre          0.273268
#              year           0.922410
#              released       0.967033
#              score          0.967033
#              votes          0.924916
#              director       0.967033
#              writer         0.967033
#              star           0.967033
#              country        0.797724
#              budget         0.411183
#              gross          0.967033
#              company        0.967033
#              runtime        0.782186
#              yearcorrect    0.828016
# genre        name           0.237624
#              rating         0.273268
#              genre          1.000000
#              year           0.027277
#              released       0.237624
#              score          0.237624
#              votes          0.229283
#              director       0.237624
#              writer         0.237624
#              star           0.237624
#              country       -0.018956
#              budget         0.443463
#              gross          0.237624
#              company        0.237624
#              runtime        0.019233
#              yearcorrect    0.162871
# year         name           0.922410
#              rating         0.922410
#              genre          0.027277
#              year           1.000000
#              released       0.922410
#              score          0.922410
#              votes          0.920425
#              director       0.922410
#              writer         0.922410
#              star           0.922410
#              country        0.872775
#              budget         0.213157
#              gross          0.922410
#              company        0.922410
#              runtime        0.749520
#              yearcorrect    0.730768
# released     name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# score        name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# votes        name           0.960719
#              rating         0.924916
#              genre          0.229283
#              year           0.920425
#              released       0.960719
#              score          0.960719
#              votes          1.000000
#              director       0.960719
#              writer         0.960719
#              star           0.960719
#              country        0.791380
#              budget         0.351262
#              gross          0.960719
#              company        0.960719
#              runtime        0.767655
#              yearcorrect    0.802079
# director     name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# writer       name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# star         name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# country      name           0.769234
#              rating         0.797724
#              genre         -0.018956
#              year           0.872775
#              released       0.769234
#              score          0.769234
#              votes          0.791380
#              director       0.769234
#              writer         0.769234
#              star           0.769234
#              country        1.000000
#              budget        -0.079357
#              gross          0.769234
#              company        0.769234
#              runtime        0.590057
#              yearcorrect    0.539956
# budget       name           0.450974
#              rating         0.411183
#              genre          0.443463
#              year           0.213157
#              released       0.450974
#              score          0.450974
#              votes          0.351262
#              director       0.450974
#              writer         0.450974
#              star           0.450974
#              country       -0.079357
#              budget         1.000000
#              gross          0.450974
#              company        0.450974
#              runtime        0.593624
#              yearcorrect    0.543037
# gross        name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# company      name           1.000000
#              rating         0.967033
#              genre          0.237624
#              year           0.922410
#              released       1.000000
#              score          1.000000
#              votes          0.960719
#              director       1.000000
#              writer         1.000000
#              star           1.000000
#              country        0.769234
#              budget         0.450974
#              gross          1.000000
#              company        1.000000
#              runtime        0.822996
#              yearcorrect    0.854302
# runtime      name           0.822996
#              rating         0.782186
#              genre          0.019233
#              year           0.749520
#              released       0.822996
#              score          0.822996
#              votes          0.767655
#              director       0.822996
#              writer         0.822996
#              star           0.822996
#              country        0.590057
#              budget         0.593624
#              gross          0.822996
#              company        0.822996
#              runtime        1.000000
#              yearcorrect    0.912360
# yearcorrect  name           0.854302
#              rating         0.828016
#              genre          0.162871
#              year           0.730768
#              released       0.854302
#              score          0.854302
#              votes          0.802079
#              director       0.854302
#              writer         0.854302
#              star           0.854302
#              country        0.539956
#              budget         0.543037
#              gross          0.854302
#              company        0.854302
#              runtime        0.912360
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# budget       country       -0.079357
# country      budget        -0.079357
# genre        country       -0.018956
# country      genre         -0.018956
# genre        runtime        0.019233
# runtime      genre          0.019233
# genre        year           0.027277
# year         genre          0.027277
# genre        yearcorrect    0.162871
# yearcorrect  genre          0.162871
# budget       year           0.213157
# year         budget         0.213157
# genre        votes          0.229283
# votes        genre          0.229283
# star         genre          0.237624
# genre        company        0.237624
#              gross          0.237624
# company      genre          0.237624
# genre        star           0.237624
#              writer         0.237624
#              director       0.237624
# score        genre          0.237624
# writer       genre          0.237624
# genre        score          0.237624
#              released       0.237624
# released     genre          0.237624
# genre        name           0.237624
# director     genre          0.237624
# name         genre          0.237624
# gross        genre          0.237624
# rating       genre          0.273268
# genre        rating         0.273268
# budget       votes          0.351262
# votes        budget         0.351262
# rating       budget         0.411183
# budget       rating         0.411183
#              genre          0.443463
# genre        budget         0.443463
# budget       company        0.450974
# name         budget         0.450974
# gross        budget         0.450974
# budget       gross          0.450974
#              star           0.450974
#              writer         0.450974
# released     budget         0.450974
# star         budget         0.450974
# score        budget         0.450974
# budget       score          0.450974
#              released       0.450974
#              name           0.450974
# writer       budget         0.450974
# company      budget         0.450974
# director     budget         0.450974
# budget       director       0.450974
# yearcorrect  country        0.539956
# country      yearcorrect    0.539956
# budget       yearcorrect    0.543037
# yearcorrect  budget         0.543037
# runtime      country        0.590057
# country      runtime        0.590057
# budget       runtime        0.593624
# runtime      budget         0.593624
# year         yearcorrect    0.730768
# yearcorrect  year           0.730768
# year         runtime        0.749520
# runtime      year           0.749520
# votes        runtime        0.767655
# runtime      votes          0.767655
# country      star           0.769234
# gross        country        0.769234
# score        country        0.769234
# country      name           0.769234
# writer       country        0.769234
# director     country        0.769234
# country      company        0.769234
#              gross          0.769234
# company      country        0.769234
# country      released       0.769234
#              director       0.769234
#              writer         0.769234
# released     country        0.769234
# star         country        0.769234
# country      score          0.769234
# name         country        0.769234
# rating       runtime        0.782186
# runtime      rating         0.782186
# votes        country        0.791380
# country      votes          0.791380
#              rating         0.797724
# rating       country        0.797724
# yearcorrect  votes          0.802079
# votes        yearcorrect    0.802079
# star         runtime        0.822996
# runtime      name           0.822996
# director     runtime        0.822996
# company      runtime        0.822996
# released     runtime        0.822996
# runtime      gross          0.822996
#              company        0.822996
# name         runtime        0.822996
# runtime      star           0.822996
#              writer         0.822996
#              director       0.822996
# writer       runtime        0.822996
# runtime      score          0.822996
#              released       0.822996
# score        runtime        0.822996
# gross        runtime        0.822996
# yearcorrect  rating         0.828016
# rating       yearcorrect    0.828016
# writer       yearcorrect    0.854302
# gross        yearcorrect    0.854302
# star         yearcorrect    0.854302
# company      yearcorrect    0.854302
# director     yearcorrect    0.854302
# yearcorrect  released       0.854302
# released     yearcorrect    0.854302
# score        yearcorrect    0.854302
# yearcorrect  score          0.854302
# name         yearcorrect    0.854302
# yearcorrect  director       0.854302
#              writer         0.854302
#              name           0.854302
#              gross          0.854302
#              star           0.854302
#              company        0.854302
# country      year           0.872775
# year         country        0.872775
# yearcorrect  runtime        0.912360
# runtime      yearcorrect    0.912360
# votes        year           0.920425
# year         votes          0.920425
#              director       0.922410
# score        year           0.922410
# year         star           0.922410
# star         year           0.922410
# year         gross          0.922410
#              company        0.922410
# released     year           0.922410
# gross        year           0.922410
# company      year           0.922410
# director     year           0.922410
# name         year           0.922410
# year         score          0.922410
#              released       0.922410
#              rating         0.922410
#              name           0.922410
# writer       year           0.922410
# rating       year           0.922410
# year         writer         0.922410
# votes        rating         0.924916
# rating       votes          0.924916
# released     votes          0.960719
# name         votes          0.960719
# gross        votes          0.960719
# votes        gross          0.960719
#              released       0.960719
#              writer         0.960719
#              star           0.960719
# director     votes          0.960719
# votes        score          0.960719
# writer       votes          0.960719
# company      votes          0.960719
# votes        name           0.960719
#              director       0.960719
# score        votes          0.960719
# star         votes          0.960719
# votes        company        0.960719
# rating       name           0.967033
# director     rating         0.967033
# rating       released       0.967033
#              score          0.967033
#              director       0.967033
# released     rating         0.967033
# name         rating         0.967033
# rating       star           0.967033
#              company        0.967033
# writer       rating         0.967033
# company      rating         0.967033
# star         rating         0.967033
# score        rating         0.967033
# gross        rating         0.967033
# rating       gross          0.967033
#              writer         0.967033
# gross        writer         1.000000
#              star           1.000000
# runtime      runtime        1.000000
# company      gross          1.000000
# gross        director       1.000000
#              company        1.000000
# company      star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
#              company        1.000000
# gross        gross          1.000000
# name         name           1.000000
# gross        released       1.000000
# score        gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# released     company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# name         company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
# score        company        1.000000
# gross        score          1.000000
# votes        votes          1.000000
# director     released       1.000000
# gross        name           1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# writer       company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# director     company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              name           1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# yearcorrect  country        0.539956
# country      yearcorrect    0.539956
# budget       yearcorrect    0.543037
# yearcorrect  budget         0.543037
# runtime      country        0.590057
# country      runtime        0.590057
# budget       runtime        0.593624
# runtime      budget         0.593624
# year         yearcorrect    0.730768
# yearcorrect  year           0.730768
# year         runtime        0.749520
# runtime      year           0.749520
# votes        runtime        0.767655
# runtime      votes          0.767655
# country      star           0.769234
# gross        country        0.769234
# score        country        0.769234
# country      name           0.769234
# writer       country        0.769234
# director     country        0.769234
# country      company        0.769234
#              gross          0.769234
# company      country        0.769234
# country      released       0.769234
#              director       0.769234
#              writer         0.769234
# released     country        0.769234
# star         country        0.769234
# country      score          0.769234
# name         country        0.769234
# rating       runtime        0.782186
# runtime      rating         0.782186
# votes        country        0.791380
# country      votes          0.791380
#              rating         0.797724
# rating       country        0.797724
# yearcorrect  votes          0.802079
# votes        yearcorrect    0.802079
# star         runtime        0.822996
# runtime      name           0.822996
# director     runtime        0.822996
# company      runtime        0.822996
# released     runtime        0.822996
# runtime      gross          0.822996
#              company        0.822996
# name         runtime        0.822996
# runtime      star           0.822996
#              writer         0.822996
#              director       0.822996
# writer       runtime        0.822996
# runtime      score          0.822996
#              released       0.822996
# score        runtime        0.822996
# gross        runtime        0.822996
# yearcorrect  rating         0.828016
# rating       yearcorrect    0.828016
# writer       yearcorrect    0.854302
# gross        yearcorrect    0.854302
# star         yearcorrect    0.854302
# company      yearcorrect    0.854302
# director     yearcorrect    0.854302
# yearcorrect  released       0.854302
# released     yearcorrect    0.854302
# score        yearcorrect    0.854302
# yearcorrect  score          0.854302
# name         yearcorrect    0.854302
# yearcorrect  director       0.854302
#              writer         0.854302
#              name           0.854302
#              gross          0.854302
#              star           0.854302
#              company        0.854302
# country      year           0.872775
# year         country        0.872775
# yearcorrect  runtime        0.912360
# runtime      yearcorrect    0.912360
# votes        year           0.920425
# year         votes          0.920425
#              director       0.922410
# score        year           0.922410
# year         star           0.922410
# star         year           0.922410
# year         gross          0.922410
#              company        0.922410
# released     year           0.922410
# gross        year           0.922410
# company      year           0.922410
# director     year           0.922410
# name         year           0.922410
# year         score          0.922410
#              released       0.922410
#              rating         0.922410
#              name           0.922410
# writer       year           0.922410
# rating       year           0.922410
# year         writer         0.922410
# votes        rating         0.924916
# rating       votes          0.924916
# released     votes          0.960719
# name         votes          0.960719
# gross        votes          0.960719
# votes        gross          0.960719
#              released       0.960719
#              writer         0.960719
#              star           0.960719
# director     votes          0.960719
# votes        score          0.960719
# writer       votes          0.960719
# company      votes          0.960719
# votes        name           0.960719
#              director       0.960719
# score        votes          0.960719
# star         votes          0.960719
# votes        company        0.960719
# rating       name           0.967033
# director     rating         0.967033
# rating       released       0.967033
#              score          0.967033
#              director       0.967033
# released     rating         0.967033
# name         rating         0.967033
# rating       star           0.967033
#              company        0.967033
# writer       rating         0.967033
# company      rating         0.967033
# star         rating         0.967033
# score        rating         0.967033
# gross        rating         0.967033
# rating       gross          0.967033
#              writer         0.967033
# gross        writer         1.000000
#              star           1.000000
# runtime      runtime        1.000000
# company      gross          1.000000
# gross        director       1.000000
#              company        1.000000
# company      star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
#              company        1.000000
# gross        gross          1.000000
# name         name           1.000000
# gross        released       1.000000
# score        gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# released     company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# name         company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
# score        company        1.000000
# gross        score          1.000000
# votes        votes          1.000000
# director     released       1.000000
# gross        name           1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# writer       company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              released       1.000000
#              name           1.000000
# director     company        1.000000
#              gross          1.000000
#              star           1.000000
#              writer         1.000000
#              director       1.000000
#              score          1.000000
#              name           1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Lucasfilm                     538375067
# Greentree                      78500541
# Warner Bros.                   46998772
# Metro-Goldwyn-Mayer (MGM)      36565280
# Dino De Laurentiis Company     30925690
# Walt Disney Productions        18000000
# Premiere Picture                5756185
# Renaissance Pictures            2956630
# Empire Pictures                 2023414
# L.P. Film                        546904
# Kôdansha                         516540
# Les Films Paul Grimault          167451
# Diversity Music                  109749
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 60                               Herbie Goes Bananas          G  Adventure
# 78                                           Babylon        NaN      Drama
# 83                      The King and the Mockingbird  Not Rated  Animation
# 96                                     The Evil Dead      NC-17     Horror
# 120                               Tarzan the Ape Man   Approved  Adventure
# 201                                         Longshot      TV-PG     Comedy
# 476                                             Dune      PG-13     Action
# 691                                      Re-Animator    Unrated     Comedy
# 982                               Devil in the Flesh          X      Drama
# 2689                              Ghost in the Shell      TV-MA  Animation
# 7607                                           Furie      TV-14     Action
#
#       year                           released  score      votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000.0
# 2     1980      June 20, 1980 (United States)    8.7  1200000.0
# 60    1980      June 25, 1980 (United States)    5.0     5300.0
# 78    1980     November 1980 (United Kingdom)    7.4     1300.0
# 83    1980            March 19, 1980 (France)    7.9     4800.0
# 96    1981     April 15, 1983 (United States)    7.5   192000.0
# 120   1981      July 24, 1981 (United States)    3.4     5300.0
# 201   1981               1981 (United States)    5.1      101.0
# 476   1984  December 14, 1984 (United States)    6.5   132000.0
# 691   1985   October 18, 1985 (United States)    7.2    59000.0
# 982   1986       May 22, 1987 (United States)    5.8     1400.0
# 2689  1995     March 29, 1996 (United States)    8.0   133000.0
# 7607  2019        February 22, 2019 (Vietnam)    6.3     4200.0
#
#               director                   writer                  star  \
# 0      Stanley Kubrick             Stephen King        Jack Nicholson
# 2       Irvin Kershner           Leigh Brackett           Mark Hamill
# 60    Vincent McEveety                 Don Tait  Charles Martin Smith
# 78        Franco Rosso             Franco Rosso       David N. Haynes
# 83       Paul Grimault  Hans Christian Andersen           Jean Martin
# 96           Sam Raimi                Sam Raimi        Bruce Campbell
# 120         John Derek                 Tom Rowe              Bo Derek
# 201    E.W. Swackhamer              Barry Rosen          Leif Garrett
# 476        David Lynch            Frank Herbert       Kyle MacLachlan
# 691      Stuart Gordon           H.P. Lovecraft         Jeffrey Combs
# 982   Marco Bellocchio         Marco Bellocchio     Maruschka Detmers
# 2689      Mamoru Oshii          Shirow Masamune         Atsuko Tanaka
# 7607       Le-Van Kiet              Le-Van Kiet          Veronica Ngo
#
#              country    budget      gross                     company  \
# 0     United Kingdom  19000000   46998772                Warner Bros.
# 2      United States  18000000  538375067                   Lucasfilm
# 60     United States  35589876   18000000     Walt Disney Productions
# 78    United Kingdom  35589876     109749             Diversity Music
# 83            France  35589876     167451     Les Films Paul Grimault
# 96     United States    350000    2956630        Renaissance Pictures
# 120    United States   6500000   36565280   Metro-Goldwyn-Mayer (MGM)
# 201    United States  35589876   78500541                   Greentree
# 476    United States  40000000   30925690  Dino De Laurentiis Company
# 691    United States    900000    2023414             Empire Pictures
# 982            Italy  35589876     546904                   L.P. Film
# 2689           Japan  35589876     516540                    Kôdansha
# 7607         Vietnam  35589876    5756185            Premiere Picture
#
#       runtime yearcorrect  Year
# 0       146.0      June 1  June
# 2       124.0      June 2  June
# 60      100.0      June 2  June
# 78       95.0      Novemb  Nove
# 83       83.0      March   Marc
# 96       85.0      April   Apri
# 120     115.0      July 2  July
# 201     100.0      1981 (  1981
# 476     137.0      Decemb  Dece
# 691     104.0      Octobe  Octo
# 982     114.0      May 22  May
# 2689     83.0      March   Marc
# 7607     98.0      Februa  Febr

# %%
df['Year'] = df['released'].astype(str).str[:4]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 60                               Herbie Goes Bananas          G  Adventure
# 78                                           Babylon        NaN      Drama
# 83                      The King and the Mockingbird  Not Rated  Animation
# 96                                     The Evil Dead      NC-17     Horror
# 120                               Tarzan the Ape Man   Approved  Adventure
# 201                                         Longshot      TV-PG     Comedy
# 476                                             Dune      PG-13     Action
# 691                                      Re-Animator    Unrated     Comedy
# 982                               Devil in the Flesh          X      Drama
# 2689                              Ghost in the Shell      TV-MA  Animation
# 7607                                           Furie      TV-14     Action
#
#       year                           released  score      votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000.0
# 2     1980      June 20, 1980 (United States)    8.7  1200000.0
# 60    1980      June 25, 1980 (United States)    5.0     5300.0
# 78    1980     November 1980 (United Kingdom)    7.4     1300.0
# 83    1980            March 19, 1980 (France)    7.9     4800.0
# 96    1981     April 15, 1983 (United States)    7.5   192000.0
# 120   1981      July 24, 1981 (United States)    3.4     5300.0
# 201   1981               1981 (United States)    5.1      101.0
# 476   1984  December 14, 1984 (United States)    6.5   132000.0
# 691   1985   October 18, 1985 (United States)    7.2    59000.0
# 982   1986       May 22, 1987 (United States)    5.8     1400.0
# 2689  1995     March 29, 1996 (United States)    8.0   133000.0
# 7607  2019        February 22, 2019 (Vietnam)    6.3     4200.0
#
#               director                   writer                  star  \
# 0      Stanley Kubrick             Stephen King        Jack Nicholson
# 2       Irvin Kershner           Leigh Brackett           Mark Hamill
# 60    Vincent McEveety                 Don Tait  Charles Martin Smith
# 78        Franco Rosso             Franco Rosso       David N. Haynes
# 83       Paul Grimault  Hans Christian Andersen           Jean Martin
# 96           Sam Raimi                Sam Raimi        Bruce Campbell
# 120         John Derek                 Tom Rowe              Bo Derek
# 201    E.W. Swackhamer              Barry Rosen          Leif Garrett
# 476        David Lynch            Frank Herbert       Kyle MacLachlan
# 691      Stuart Gordon           H.P. Lovecraft         Jeffrey Combs
# 982   Marco Bellocchio         Marco Bellocchio     Maruschka Detmers
# 2689      Mamoru Oshii          Shirow Masamune         Atsuko Tanaka
# 7607       Le-Van Kiet              Le-Van Kiet          Veronica Ngo
#
#              country    budget      gross                     company  \
# 0     United Kingdom  19000000   46998772                Warner Bros.
# 2      United States  18000000  538375067                   Lucasfilm
# 60     United States  35589876   18000000     Walt Disney Productions
# 78    United Kingdom  35589876     109749             Diversity Music
# 83            France  35589876     167451     Les Films Paul Grimault
# 96     United States    350000    2956630        Renaissance Pictures
# 120    United States   6500000   36565280   Metro-Goldwyn-Mayer (MGM)
# 201    United States  35589876   78500541                   Greentree
# 476    United States  40000000   30925690  Dino De Laurentiis Company
# 691    United States    900000    2023414             Empire Pictures
# 982            Italy  35589876     546904                   L.P. Film
# 2689           Japan  35589876     516540                    Kôdansha
# 7607         Vietnam  35589876    5756185            Premiere Picture
#
#       runtime yearcorrect  Year
# 0       146.0      June 1  June
# 2       124.0      June 2  June
# 60      100.0      June 2  June
# 78       95.0      Novemb  Nove
# 83       83.0      March   Marc
# 96       85.0      April   Apri
# 120     115.0      July 2  July
# 201     100.0      1981 (  1981
# 476     137.0      Decemb  Dece
# 691     104.0      Octobe  Octo
# 982     114.0      May 22  May
# 2689     83.0      March   Marc
# 7607     98.0      Februa  Febr

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                     year
# Lucasfilm                   1980    538375067
# Greentree                   1981     78500541
# Warner Bros.                1980     46998772
# Metro-Goldwyn-Mayer (MGM)   1981     36565280
# Dino De Laurentiis Company  1984     30925690
# Walt Disney Productions     1980     18000000
# Premiere Picture            2019      5756185
# Renaissance Pictures        1981      2956630
# Empire Pictures             1985      2023414
# L.P. Film                   1986       546904
# Kôdansha                    1995       516540
# Les Films Paul Grimault     1980       167451
# Diversity Music             1980       109749
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Lucasfilm                     538375067
# Greentree                      78500541
# Warner Bros.                   46998772
# Metro-Goldwyn-Mayer (MGM)      36565280
# Dino De Laurentiis Company     30925690
# Walt Disney Productions        18000000
# Premiere Picture                5756185
# Renaissance Pictures            2956630
# Empire Pictures                 2023414
# L.P. Film                        546904
# Kôdansha                         516540
# Les Films Paul Grimault          167451
# Diversity Music                  109749
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0       12       6      4  1980         5    8.4   927000.0        10      11
# 2        8       4      0  1980         6    8.7  1200000.0         3       7
# 60       5       1      1  1980         7    5.0     5300.0        12       1
# 78       0      -1      4  1980        11    7.4     1300.0         2       2
# 83      11       3      2  1980         8    7.9     4800.0         8       5
# 96      10       2      5  1981         1    7.5   192000.0         9       9
# 120      9       0      1  1981         4    3.4     5300.0         4      12
# 201      6       9      3  1981         0    5.1      101.0         1       0
# 476      2       5      0  1984         2    6.5   132000.0         0       3
# 691      7      10      3  1985        12    7.2    59000.0        11       4
# 982      1      11      4  1986        10    5.8     1400.0         7       8
# 2689     4       8      2  1995         9    8.0   133000.0         6      10
# 7607     3       7      0  2019         3    6.3     4200.0         5       6
#
#       star  country    budget      gross  company  runtime  yearcorrect  Year
# 0        5        3  19000000   46998772       12    146.0            5     5
# 2       10        4  18000000  538375067        7    124.0            6     5
# 60       3        4  35589876   18000000       11    100.0            6     5
# 78       4        3  35589876     109749        1     95.0            9     8
# 83       6        0  35589876     167451        6     83.0            7     6
# 96       2        4    350000    2956630       10     85.0            1     1
# 120      1        4   6500000   36565280        8    115.0            4     4
# 201      9        4  35589876   78500541        3    100.0            0     0
# 476      8        4  40000000   30925690        0    137.0            2     2
# 691      7        4    900000    2023414        2    104.0           10     9
# 982     11        1  35589876     546904        5    114.0            8     7
# 2689     0        2  35589876     516540        4     83.0            7     6
# 7607    12        5  35589876    5756185        9     98.0            3     3

# %%
df_numerized.corr(method='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.164835  0.135319 -0.355137 -0.263736  0.212898
# rating      -0.164835  1.000000  0.110715  0.353175  0.104396  0.107832
# genre        0.135319  0.110715  1.000000 -0.362923  0.196827  0.200473
# year        -0.355137  0.353175 -0.362923  1.000000 -0.092218 -0.021987
# released    -0.263736  0.104396  0.196827 -0.092218  1.000000  0.276491
# score        0.212898  0.107832  0.200473 -0.021987  0.276491  1.000000
# votes        0.438670 -0.011122 -0.098628 -0.226581 -0.090934  0.587857
# director     0.434066  0.071429  0.332146 -0.070635  0.362637  0.143775
# writer       0.428571  0.005495  0.123017  0.103990 -0.016484  0.141010
# star        -0.285714  0.532967 -0.246034  0.355137 -0.098901  0.053916
# country     -0.060138 -0.135312 -0.326254  0.249032 -0.496142 -0.280801
# budget      -0.601427  0.114006 -0.286700  0.255045  0.036480 -0.046693
# gross        0.193236 -0.060853 -0.391976 -0.195022 -0.104270  0.320245
# company      0.576923 -0.247253  0.024603  0.078483 -0.280220 -0.029032
# runtime      0.085706  0.112489 -0.200007 -0.208971 -0.185340  0.002302
# yearcorrect -0.194126  0.062398  0.144479 -0.107983  0.991431  0.303125
# Year        -0.177120  0.064407  0.160841 -0.088682  0.982212  0.290293
#
#                 votes  director    writer      star   country    budget  \
# name         0.438670  0.434066  0.428571 -0.285714 -0.060138 -0.601427
# rating      -0.011122  0.071429  0.005495  0.532967 -0.135312  0.114006
# genre       -0.098628  0.332146  0.123017 -0.246034 -0.326254 -0.286700
# year        -0.226581 -0.070635  0.103990  0.355137  0.249032  0.255045
# released    -0.090934  0.362637 -0.016484 -0.098901 -0.496142  0.036480
# score        0.587857  0.143775  0.141010  0.053916 -0.280801 -0.046693
# votes        1.000000  0.011473  0.352292  0.143488  0.125522 -0.266815
# director     0.011473  1.000000  0.208791 -0.280220 -0.180415 -0.378051
# writer       0.352292  0.208791  1.000000 -0.329670 -0.165381 -0.470173
# star         0.143488 -0.280220 -0.329670  1.000000  0.090208  0.299454
# country      0.125522 -0.180415 -0.165381  0.090208  1.000000 -0.326851
# budget      -0.266815 -0.378051 -0.470173  0.299454 -0.326851  1.000000
# gross        0.786899 -0.286494  0.050714  0.320835  0.216765 -0.146959
# company      0.344124  0.582418  0.461538 -0.181319  0.135312 -0.295399
# runtime      0.579335 -0.174626  0.189625  0.303186  0.239253 -0.066769
# yearcorrect -0.000553  0.374387  0.020799 -0.076264 -0.468438 -0.008223
# Year         0.001801  0.378393  0.064407 -0.080509 -0.442289 -0.045769
#
#                 gross   company   runtime  yearcorrect      Year
# name         0.193236  0.576923  0.085706    -0.194126 -0.177120
# rating      -0.060853 -0.247253  0.112489     0.062398  0.064407
# genre       -0.391976  0.024603 -0.200007     0.144479  0.160841
# year        -0.195022  0.078483 -0.208971    -0.107983 -0.088682
# released    -0.104270 -0.280220 -0.185340     0.991431  0.982212
# score        0.320245 -0.029032  0.002302     0.303125  0.290293
# votes        0.786899  0.344124  0.579335    -0.000553  0.001801
# director    -0.286494  0.582418 -0.174626     0.374387  0.378393
# writer       0.050714  0.461538  0.189625     0.020799  0.064407
# star         0.320835 -0.181319  0.303186    -0.076264 -0.080509
# country      0.216765  0.135312  0.239253    -0.468438 -0.442289
# budget      -0.146959 -0.295399 -0.066769    -0.008223 -0.045769
# gross        1.000000  0.085117  0.336978    -0.027891 -0.064513
# company      0.085117  1.000000  0.076064    -0.221859 -0.209324
# runtime      0.336978  0.076064  1.000000    -0.112721 -0.064602
# yearcorrect -0.027891 -0.221859 -0.112721     1.000000  0.994783
# Year        -0.064513 -0.209324 -0.064602     0.994783  1.000000

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()
